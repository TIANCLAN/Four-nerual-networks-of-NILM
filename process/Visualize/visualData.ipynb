# %%
import numpy as np
test=np.load('NILM_Disag_Fridge/ukdale/DAE/logs/model/House_2/20220414-200648/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Fridge=[]
Fridge_DAE=[]
Fridge_DAE.append(min(test[0]))#MAE
Fridge_DAE.append(max(test[1]))#ACC
Fridge_DAE.append(max(test[2]))#PREC
Fridge_DAE.append(max(test[3]))#RECALL
Fridge_DAE.append(max(test[4]))#F1
Fridge_DAE.append(max(test[5]))#SAE
Fridge.append(Fridge_DAE)

test=np.load('NILM_Disag_Fridge/ukdale/VAE/logs/model/House_2/20220414-200632/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Fridge_VAE=[]
Fridge_VAE.append(min(test[0]))
Fridge_VAE.append(max(test[1]))
Fridge_VAE.append(max(test[2]))
Fridge_VAE.append(max(test[3]))
Fridge_VAE.append(max(test[4]))
Fridge_VAE.append(max(test[5]))
Fridge.append(Fridge_VAE)

test=np.load('NILM_Disag_Fridge/ukdale/S2S/logs/model/House_2/20220414-200805/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Fridge_S2S=[]
Fridge_S2S.append(min(test[0]))
Fridge_S2S.append(max(test[1]))
Fridge_S2S.append(max(test[2]))
Fridge_S2S.append(max(test[3]))
Fridge_S2S.append(max(test[4]))
Fridge_S2S.append(max(test[5]))
Fridge.append(Fridge_S2S)

##无
test=np.load('NILM_Disag_WashingMachine/ukdale/S2P/logs/model/House_2/20220407-234423/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
Fridge_S2P=[]
Fridge_S2P.append(min(test[0]))
Fridge_S2P.append(max(test[1]))
Fridge_S2P.append(max(test[2]))
Fridge_S2P.append(max(test[3]))
Fridge_S2P.append(max(test[4]))
Fridge_S2P.append(max(test[5]))
Fridge.append(Fridge_S2P)
Fridge
# Out:
# [[20.508041498395816,
#   0.905276969084523,
#   0.9259585396482998,
#   0.708281303401328,
#   0.7982012981465968,
#   0.2732477575899045],
#  [14.536005125193002,
#   0.9416211036347449,
#   0.9197356497261129,
#   0.8994237012663144,
#   0.9045863642798877,
#   0.16095599008793923],
#  [21.486679414766513,
#   0.8732039054117373,
#   0.9448527887402516,
#   0.7595545572901082,
#   0.8381878589898244,
#   0.34728352553495173],
#  [12.402755741069768,
#   0.9993501914064139,
#   0.36915478520175193,
#   0.9916646474436637,
#   0.5332346210795531,
#   0.7214108433859048]]

# %%
import numpy as np
test=np.load('NILM_Disag_WashingMachine/ukdale/VAE/logs/model/House_2/20220407-150330/pred_1.npy',encoding = "latin1",allow_pickle=True)  #加载文件
test
# Out:
# array([[[252., 254., 252., ..., 185., 186., 185.]],
#
#        [[  0.,   0.,   0., ...,   0.,   0.,   0.]],
#
#        [[  3.,   3.,   3., ...,   3.,   3.,   3.]]])

# %%
import numpy as np
##DAE尚未
test=np.load('NILM_Disag_WashingMachine/ukdale/VAE/logs/model/House_2/20220407-150330/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
WashingMachine=[]
WashingMachine_DAE=[]
WashingMachine_DAE.append(min(test[0]))#MAE
WashingMachine_DAE.append(max(test[1]))#ACC
WashingMachine_DAE.append(max(test[2]))#PREC
WashingMachine_DAE.append(max(test[3]))#RECALL
WashingMachine_DAE.append(max(test[4]))#F1
WashingMachine_DAE.append(max(test[5]))#SAE
WashingMachine.append(WashingMachine_DAE)

test=np.load('NILM_Disag_WashingMachine/ukdale/VAE/logs/model/House_2/20220407-150330/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
WashingMachine_VAE=[]
WashingMachine_VAE.append(min(test[0]))
WashingMachine_VAE.append(max(test[1]))
WashingMachine_VAE.append(max(test[2]))
WashingMachine_VAE.append(max(test[3]))
WashingMachine_VAE.append(max(test[4]))
WashingMachine_VAE.append(max(test[5]))
WashingMachine.append(WashingMachine_VAE)

test=np.load('NILM_Disag_WashingMachine/ukdale/S2S/logs/model/House_2/20220408-152921/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
WashingMachine_S2S=[]
WashingMachine_S2S.append(min(test[0]))
WashingMachine_S2S.append(max(test[1]))
WashingMachine_S2S.append(max(test[2]))
WashingMachine_S2S.append(max(test[3]))
WashingMachine_S2S.append(max(test[4]))
WashingMachine_S2S.append(max(test[5]))
WashingMachine.append(WashingMachine_S2S)

test=np.load('NILM_Disag_WashingMachine/ukdale/S2P/logs/model/House_2/20220407-234423/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
WashingMachine_S2P=[]
WashingMachine_S2P.append(min(test[0]))
WashingMachine_S2P.append(max(test[1]))
WashingMachine_S2P.append(max(test[2]))
WashingMachine_S2P.append(max(test[3]))
WashingMachine_S2P.append(max(test[4]))
WashingMachine_S2P.append(max(test[5]))
WashingMachine.append(WashingMachine_S2P)
WashingMachine
# Out:
# [[5.762950024091013,
#   0.8160730533136117,
#   0.8685187670558762,
#   0.959970923188757,
#   0.9099816007359707,
#   0.42967649645724154],
#  [5.762950024091013,
#   0.8160730533136117,
#   0.8685187670558762,
#   0.959970923188757,
#   0.9099816007359707,
#   0.42967649645724154],
#  [9.586902414869,
#   0.9391133265248358,
#   0.5164636321932821,
#   0.9968015507632663,
#   0.6769328411804988,
#   0.5606545527848638],
#  [12.402755741069768,
#   0.9993501914064139,
#   0.36915478520175193,
#   0.9916646474436637,
#   0.5332346210795531,
#   0.7214108433859048]]

# %%
import numpy as np
test=np.load('NILM_Disag_Kettle/ukdale/DAE/logs/model/House_2/20220413-233220/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Kettle=[]
Kettle_DAE=[]
Kettle_DAE.append(min(test[0]))#MAE
Kettle_DAE.append(max(test[1]))#ACC
Kettle_DAE.append(max(test[2]))#PREC
Kettle_DAE.append(max(test[3]))#RECALL
Kettle_DAE.append(max(test[4]))#F1
Kettle_DAE.append(max(test[5]))#SAE
Kettle.append(Kettle_DAE)

##
test=np.load('NILM_Disag_WashingMachine/ukdale/VAE/logs/model/House_2/20220407-150330/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Kettle_VAE=[]
Kettle_VAE.append(min(test[0]))
Kettle_VAE.append(max(test[1]))
Kettle_VAE.append(max(test[2]))
Kettle_VAE.append(max(test[3]))
Kettle_VAE.append(max(test[4]))
Kettle_VAE.append(max(test[5]))
Kettle.append(Kettle_VAE)

test=np.load('NILM_Disag_Kettle/ukdale/S2S/logs/model/House_2/20220415-003549/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Kettle_S2S=[]
Kettle_S2S.append(min(test[0]))
Kettle_S2S.append(max(test[1]))
Kettle_S2S.append(max(test[2]))
Kettle_S2S.append(max(test[3]))
Kettle_S2S.append(max(test[4]))
Kettle_S2S.append(max(test[5]))
Kettle.append(Kettle_S2S)

test=np.load('NILM_Disag_Kettle/ukdale/S2P/logs/model/House_2/20220415-003603/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
Kettle_S2P=[]
Kettle_S2P.append(min(test[0]))
Kettle_S2P.append(max(test[1]))
Kettle_S2P.append(max(test[2]))
Kettle_S2P.append(max(test[3]))
Kettle_S2P.append(max(test[4]))
Kettle_S2P.append(max(test[5]))
Kettle.append(Kettle_S2P)
Kettle
# Out:
# [[12.625449023209647,
#   0.8413066784059889,
#   0.8173465346534653,
#   0.9975900130139297,
#   0.897362871491619,
#   0.45785130047258615],
#  [5.762950024091013,
#   0.8160730533136117,
#   0.8685187670558762,
#   0.959970923188757,
#   0.9099816007359707,
#   0.42967649645724154],
#  [12.946515297272258,
#   0.8368898661969298,
#   0.7870901561490825,
#   0.9988914059864077,
#   0.8803008413359394,
#   0.4188461790141448],
#  [8.94901520004053,
#   0.8831362381458405,
#   0.9328602620087336,
#   0.9970598158769942,
#   0.9598652032482274,
#   0.3822804834942164]]

# %%
import numpy as np
test=np.load('NILM_Disag_Microwave/ukdale/DAE/logs/model/House_2/20220409-081553/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Microwave=[]
Microwave_DAE=[]
Microwave_DAE.append(min(test[0]))#MAE
Microwave_DAE.append(max(test[1]))#ACC
Microwave_DAE.append(max(test[2]))#PREC
Microwave_DAE.append(max(test[3]))#RECALL
Microwave_DAE.append(max(test[4]))#F1
Microwave_DAE.append(max(test[5]))#SAE
Microwave.append(Microwave_DAE)

##
test=np.load('NILM_Disag_Microwave/ukdale/VAE/logs/model/House_2/20220410-175322/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Microwave_VAE=[]
Microwave_VAE.append(min(test[0]))
Microwave_VAE.append(max(test[1]))
Microwave_VAE.append(max(test[2]))
Microwave_VAE.append(max(test[3]))
Microwave_VAE.append(max(test[4]))
Microwave_VAE.append(max(test[5]))
Microwave.append(Microwave_VAE)

test=np.load('NILM_Disag_Kettle/ukdale/S2S/logs/model/House_2/20220415-003549/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
Microwave_S2S=[]
Microwave_S2S.append(min(test[0]))
Microwave_S2S.append(max(test[1]))
Microwave_S2S.append(max(test[2]))
Microwave_S2S.append(max(test[3]))
Microwave_S2S.append(max(test[4]))
Microwave_S2S.append(max(test[5]))
Microwave.append(Microwave_S2S)

##
test=np.load('NILM_Disag_Microwave/ukdale/S2P/logs/model/House_2/20220408-194834/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
Microwave_S2P=[]
Microwave_S2P.append(min(test[0]))
Microwave_S2P.append(max(test[1]))
Microwave_S2P.append(max(test[2]))
Microwave_S2P.append(max(test[3]))
Microwave_S2P.append(max(test[4]))
Microwave_S2P.append(max(test[5]))
Microwave.append(Microwave_S2P)
Microwave
# Out:
# [[9.236477169954902,
#   0.9942927302477531,
#   0.7489574645537949,
#   0.28356973995271867,
#   0.3682271680736761,
#   0.7401115623632071],
#  [4.424716419283152,
#   0.8779108593399721,
#   0.8679103071415112,
#   0.5820330969267139,
#   0.6760486030067961,
#   0.37836367244362595],
#  [12.946515297272258,
#   0.8368898661969298,
#   0.7870901561490825,
#   0.9988914059864077,
#   0.8803008413359394,
#   0.4188461790141448],
#  [8.813851287500823,
#   0.9951315969812055,
#   0.6290672451193059,
#   0.4962174940898345,
#   0.30999465526456443,
#   1.3291828298324808]]

# %%
import numpy as np
test=np.load('NILM_Disag_Microwave/ukdale/DAE/logs/model/House_2/20220409-081553/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
DishWasher=[]
DishWasher_DAE=[]
DishWasher_DAE.append(min(test[0]))#MAE
DishWasher_DAE.append(max(test[1]))#ACC
DishWasher_DAE.append(max(test[2]))#PREC
DishWasher_DAE.append(max(test[3]))#RECALL
DishWasher_DAE.append(max(test[4]))#F1
DishWasher_DAE.append(max(test[5]))#SAE
DishWasher.append(DishWasher_DAE)

##
test=np.load('NILM_Disag_Dishwasher/ukdale/VAE/logs/model/House_2/20220415-084713/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
DishWasher_VAE=[]
DishWasher_VAE.append(min(test[0]))
DishWasher_VAE.append(max(test[1]))
DishWasher_VAE.append(max(test[2]))
DishWasher_VAE.append(max(test[3]))
DishWasher_VAE.append(max(test[4]))
DishWasher_VAE.append(max(test[5]))
DishWasher.append(DishWasher_VAE)

test=np.load('NILM_Disag_Kettle/ukdale/S2S/logs/model/House_2/20220415-003549/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
DishWasher_S2S=[]
DishWasher_S2S.append(min(test[0]))
DishWasher_S2S.append(max(test[1]))
DishWasher_S2S.append(max(test[2]))
DishWasher_S2S.append(max(test[3]))
DishWasher_S2S.append(max(test[4]))
DishWasher_S2S.append(max(test[5]))
DishWasher.append(DishWasher_S2S)

##
test=np.load('NILM_Disag_Microwave/ukdale/S2P/logs/model/House_2/20220408-194834/results_median.npy',encoding = "latin1",allow_pickle=True)  #加载文件
DishWasher_S2P=[]
DishWasher_S2P.append(min(test[0]))
DishWasher_S2P.append(max(test[1]))
DishWasher_S2P.append(max(test[2]))
DishWasher_S2P.append(max(test[3]))
DishWasher_S2P.append(max(test[4]))
DishWasher_S2P.append(max(test[5]))
DishWasher.append(DishWasher_S2P)
DishWasher
# Out:
# [[9.236477169954902,
#   0.9942927302477531,
#   0.7489574645537949,
#   0.28356973995271867,
#   0.3682271680736761,
#   0.7401115623632071],
#  [10.548260118272657,
#   0.9261022410032987,
#   0.99582895532843,
#   0.8136877406533349,
#   0.8686408839779005,
#   0.3400270601145401],
#  [12.946515297272258,
#   0.8368898661969298,
#   0.7870901561490825,
#   0.9988914059864077,
#   0.8803008413359394,
#   0.4188461790141448],
#  [8.813851287500823,
#   0.9951315969812055,
#   0.6290672451193059,
#   0.4962174940898345,
#   0.30999465526456443,
#   1.3291828298324808]]

# %%
import numpy as np
import matplotlib.pyplot as plt
language = ('DAE', 'VAE', 'S2S', 'S2P')
x_pos = range(len(language)) # [0, 1, 2, 3, 4, 5, 6]
#pop = [max(test[1]), max(test[2]), max(test[3]), max(test[4]), max(test[5])]

pop = [Fridge[0][2],Fridge[1][2],Fridge[2][2],Fridge[3][2]]
plt.figure(figsize=(15,12))
plt.subplot(5,5,1)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
plt.ylabel('PREC')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Fridge')

pop = [Kettle[0][2],Kettle[1][2],Kettle[2][2],Kettle[3][2]]
plt.subplot(5,5,2)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Kettle')


pop = [Microwave[0][2],Microwave[1][2],Microwave[2][2],Microwave[3][2]]
plt.subplot(5,5,3)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Microwave')

pop = [DishWasher[0][2],DishWasher[1][2],DishWasher[2][2],DishWasher[3][2]]
plt.subplot(5,5,4)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('DishWasher--Multi')

pop = [WashingMachine[0][2],WashingMachine[1][2],WashingMachine[2][2],WashingMachine[3][2]]
plt.subplot(5,5,5)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('WashingMachine--Multi')


pop = [Fridge[0][3],Fridge[1][3],Fridge[2][3],Fridge[3][3]]
plt.subplot(5,5,6)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
plt.ylabel('RECALL')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Kettle[0][3],Kettle[1][3],Kettle[2][3],Kettle[3][3]]
plt.subplot(5,5,7)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Microwave[0][3],Microwave[1][3],Microwave[2][3],Microwave[3][3]]
plt.subplot(5,5,8)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [DishWasher[0][3],DishWasher[1][3],DishWasher[2][3],DishWasher[3][3]]
plt.subplot(5,5,9)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

    pop = [WashingMachine[0][3],WashingMachine[1][3],WashingMachine[2][3],WashingMachine[3][3]]
plt.subplot(5,5,10)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)




pop = [Fridge[0][4],Fridge[1][4],Fridge[2][4],Fridge[3][4]]
plt.subplot(5,5,11)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
plt.ylabel('F1-Score')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Kettle[0][4],Kettle[1][4],Kettle[2][4],Kettle[3][4]]
plt.subplot(5,5,12)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
    
pop = [Microwave[0][4],Microwave[1][4],Microwave[2][4],Microwave[3][4]]
plt.subplot(5,5,13)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [DishWasher[0][4],DishWasher[1][4],DishWasher[2][4],DishWasher[3][4]]
plt.subplot(5,5,14)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [WashingMachine[0][4],WashingMachine[1][4],WashingMachine[2][4],WashingMachine[3][4]]
plt.subplot(5,5,15)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)


#pop = [max(test[1]), max(test[2]), max(test[3]), max(test[4]), max(test[5])]
pop = [Fridge[0][0],Fridge[1][0],Fridge[2][0],Fridge[3][0]]
plt.subplot(5,5,16)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 30))
plt.ylabel('Mean Absolute Error')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Kettle[0][0],Kettle[1][0],Kettle[2][0],Kettle[3][0]]
plt.subplot(5,5,17)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 30))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Microwave[0][0],Microwave[1][0],Microwave[2][0],Microwave[3][0]]
plt.subplot(5,5,18)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 30))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [DishWasher[0][0],DishWasher[1][0],DishWasher[2][0],DishWasher[3][0]]
plt.subplot(5,5,19)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 30))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [WashingMachine[0][0],WashingMachine[1][0],WashingMachine[2][0],WashingMachine[3][0]]
plt.subplot(5,5,20)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 30))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)    



pop = [Fridge[0][1],Fridge[1][1],Fridge[2][1],Fridge[3][1]]
plt.subplot(5,5,21)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
plt.ylabel('Accuracy')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Kettle[0][1],Kettle[1][1],Kettle[2][1],Kettle[3][1]]
plt.subplot(5,5,22)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [Microwave[0][1],Microwave[1][1],Microwave[2][1],Microwave[3][1]]
plt.subplot(5,5,23)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [DishWasher[0][1],DishWasher[1][1],DishWasher[2][1],DishWasher[3][1]]
plt.subplot(5,5,24)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

pop = [WashingMachine[0][1],WashingMachine[1][1],WashingMachine[2][1],WashingMachine[3][1]]
plt.subplot(5,5,25)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)

#print("Mean absolute Error:", min(test[0]))
plt.savefig("demo.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
language = ('DAE', 'VAE', 'S2S', 'S2P')
x_pos = range(len(language)) # [0, 1, 2, 3, 4, 5, 6]
#pop = [max(test[1]), max(test[2]), max(test[3]), max(test[4]), max(test[5])]
pop = [Fridge[0][1],Fridge[1][1],Fridge[2][1],Fridge[3][1]]
plt.figure(figsize=(15,4))
plt.subplot(1,5,1)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
plt.ylabel('Accuracy')
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Fridge')

pop = [WashingMachine[0][1],WashingMachine[1][1],WashingMachine[2][1],WashingMachine[3][1]]
plt.subplot(1,5,2)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('WashingMachine')

pop = [Microwave[0][1],Microwave[1][1],Microwave[2][1],Microwave[3][1]]
plt.subplot(1,5,3)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Microwave')

pop = [DishWasher[0][1],DishWasher[1][1],DishWasher[2][1],DishWasher[3][1]]
plt.subplot(1,5,4)
plt.bar(x_pos, pop, align='center', color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('DishWasher')

pop = [Kettle[0][1],Kettle[1][1],Kettle[2][1],Kettle[3][1]]
plt.subplot(1,5,5)
plt.bar(x_pos, pop, align='center',color=['yellowgreen','gold','darkorange','red'],width=1)
plt.xticks(x_pos, language)
plt.ylim((0, 1))
for a,b in zip(x_pos,pop):
    plt.text(a, b-0.07, '%.3f' % b, ha='center', va= 'bottom',fontsize=10)
plt.title('Kettle')


#print("Mean absolute Error:", min(test[0]))
#plt.savefig(\"demo4.png\")
# Out:
# Text(0.5, 1.0, 'Kettle')

# %%
import numpy as np
test=np.load('../../data/NILM/NILM_Disag_Microwave/ukdale/VAE/logs/model/House_12/20220715-172909/results_median.npy',encoding = "latin1",allow_pickle=True)
#doc = open('1.txt', 'a')  #打开一个存储文件，并依次写入
#print(test, file=doc)  #将打印内容写入文件中
print(test)
# Out:
# []
